# %%
import os
import numpy as np
import pandas as pd

# %%
bob = pd.read_csv('./pad/bobaadr.txt')
# Out:
# /opt/rh/anaconda/root/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
bob['bbl']=bob.boro*1000000000 + bob.block*10000 + bob.lot

# %%
bob.drop(['lhnd','lcontpar','lsos','hhnd','hhns','hcontpar','lhns','hsos','scboro','sc5','sclgc','stname','addrtype',
          'validlgcs','realb7sc','parity','b10sc','segid'], axis=1, inplace=True)

# %%
bob
# Out:
#          boro  block   lot      bin          lhnd         lhns lcontpar lsos  \
# 0           1      1    10  1000000  38            000038000AA
# 1           1      1    10  1000000                                        R
# 2           1      1    10  1000000  39A           000039000MB        L    L
# 3           1      1    10  1000000  39B           000039000MC        L    L
# 4           1      1    10  1086268
# 5           1      1    10  1086268  920           000920000AA        R    R
# 6           1      1    10  1086268  920           000920000AA        R    R
# 7           1      1    10  1086270  929           000929000AA        R    R
# 8           1      1    10  1086270
# 9           1      1    10  1086270  929           000929000AA        R    R
# 10          1      1    10  1086271
# 11          1      1    10  1086271  928           000928000AA        R    R
# 12          1      1    10  1086271  928           000928000AA        R    R
# ...

# %%
bob.to_csv("./pad/bob.csv")
